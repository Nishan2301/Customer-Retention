# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)
os.getcwd()
# Out:
# 'C:\\Users\\Zayn'

# %%
os.chdir('C:\Jpnb files')

# %%
df = pd.read_excel(r"C:\Users\Zayn\Documents\Juypter Notebook Files\customer_retention_dataset(2).xlsx")
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    int64
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.sum()
# Out:
# 1Gender of respondent                                                                                                 180
# 2 How old are you?                                                                                                    796
# 3 Which city do you shop online from?                                   DelhiDelhiGreater NoidaKarnal Bangalore NoidaD...
# 4 What is the Pin Code of where you shop online from?                                                            59305286
# 5 Since How Long You are Shopping Online ?                                                                            948
#                                                                                               ...
# Longer delivery period                                                  Paytm.comSnapdeal.comPaytm.comPaytm.comPaytm.c...
# Change in website/Application design                                    Flipkart.comAmazon.inPaytm.comAmazon.in, Flipk...
# ...

# %%
df.describe().T
# Out:
#                                                     count           mean  \
# 1Gender of respondent                               269.0       0.669145
# 2 How old are you?                                  269.0       2.959108
# 4 What is the Pin Code of where you shop online...  269.0  220465.747212
# 5 Since How Long You are Shopping Online ?          269.0       3.524164
# 6 How many times you have made an online purcha...  269.0       2.672862
# 7 How do you access the internet while shopping...  269.0       3.260223
# 8 Which device do you use to access the online ...  269.0       1.676580
# 9 What is the screen size of your mobile device...  269.0       4.282528
# 10 What is the operating system (OS) of your de...  269.0       1.776952
# 11 What browser do you run on your device to ac...  269.0       1.275093
# 12 Which channel did you follow to arrive at yo...  269.0       1.360595
# 13 After first visit, how do you reach the onli...  269.0       2.546468
# ...

# %%
df.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
pd.options.display.max_columns = None

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot(df['45 You feel gratification shopping on your favorite e-tailer'])
# Out:
# C:\Users\Zayn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='45 You feel gratification shopping on your favorite e-tailer', ylabel='count'>

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot(df['46 Shopping on the website helps you fulfill certain roles'])
# Out:
# C:\Users\Zayn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='46 Shopping on the website helps you fulfill certain roles', ylabel='count'>

# %%
plt.subplot(1,2,1)
sns.countplot(df['30 Online shopping gives monetary benefit and discounts'])
# Out:
# C:\Users\Zayn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='30 Online shopping gives monetary benefit and discounts', ylabel='count'>

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot(df['44 Shopping on your preferred e-tailer enhances your social status'])
# Out:
# C:\Users\Zayn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='44 Shopping on your preferred e-tailer enhances your social status', ylabel='count'>

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot(df['43 Shopping on the website gives you the sense of adventure'])
# Out:
# C:\Users\Zayn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='43 Shopping on the website gives you the sense of adventure', ylabel='count'>

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot(df['41 Monetary savings'])
# Out:
# C:\Users\Zayn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='41 Monetary savings', ylabel='count'>

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot(df['42 The Convenience of patronizing the online retailer'])
# Out:
# C:\Users\Zayn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='42 The Convenience of patronizing the online retailer', ylabel='count'>

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot(df['40 Provision of complete and relevant product information'])
# Out:
# C:\Users\Zayn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='40 Provision of complete and relevant product information', ylabel='count'>

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.countplot(df['39 Offering a wide variety of listed product in several category'])
# Out:
# C:\Users\Zayn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='39 Offering a wide variety of listed product in several category', ylabel='count'>

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df = pd.DataFrame(data = df)

# %%
dflist = ['30 Online shopping gives monetary benefit and discounts',
       '43 Shopping on the website gives you the sense of adventure',
       '44 Shopping on your preferred e-tailer enhances your social status',
       '45 You feel gratification shopping on your favorite e-tailer',
       '46 Shopping on the website helps you fulfill certain roles']
df['hedonic_value'] = df[dflist].sum(axis=1)
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
dflist = ['39 Offering a wide variety of listed product in several category',
       '40 Provision of complete and relevant product information',
       '41 Monetary savings',
       '42 The Convenience of patronizing the online retailer',]
df['utilitarian_value'] = df[dflist].sum(axis=1)
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
dflist = ['hedonic_value',
         'utilitarian_value']
df['Custome_retention'] = df[dflist].sum(axis=1)
df
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...
